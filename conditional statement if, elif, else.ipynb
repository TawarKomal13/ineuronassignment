# %%
# "==" is a comparison operator "=" is an assignment operator
a=10
if a==10:
    print("this is my first condition")
# Out:
# this is my first condition

# %%
# wont give output bcz of no else condition
a=10
if a==11:
    print("this is my first condition")

# %%
a=10
if a>5:
    pass

# %%
a=10
if a>8:
    print("print if condition is true")
# Out:
# print if condition is true

# %%
# wont give output cz condition is falseif
a=10
if a<8:
    print("print if condition is true")

# %%
a=10
if a!=11:
    print("my condition is false")
else:
    print("print this")
# Out:
# my condition is false

# %%
a=10
if a==11:
    print("my condition is false")
else:
    print("print this")
# Out:
# print this

# %%
a=10
if a==12:
    print("here we're trying to compare 10 with 12")
elif a==11:
    print("here we are trying to compare 10 with 11")
else:
    print("if all the blocks will fail then do this")
# Out:
# if all the blocks will fail then do this

# %%
a=10
if a==12:
    print("here we're trying to compare 10 with 12")
elif a==10:
    print("here we are trying to compare 10 with 11")
else:
    print("if all the blocks will fail then do this")
# Out:
# here we are trying to compare 10 with 11

# %%
# must not give condition to else block
price=500
if price>500:
    print("I wont be able to buy jacket")
elif price<500:
    print("I will be able to buy a jacket")
else price==500:
    print("i dont know")
# Out:
#   File "C:\Users\Komal\AppData\Local\Temp/ipykernel_13112/2003225470.py", line 7
#     else price==500:
#          ^
# SyntaxError: invalid syntax

# %%
price=500
if price>500:
    print("I wont be able to buy jacket")
elif price<500:
    print("I will be able to buy a jacket")
elif price==500:
    print("for sure i will be able to buy that jacket")
else:
    print("i dont know")
# Out:
# for sure i will be able to buy that jacket

# %%
price>500
# Out:
# False

# %%
price<500
# Out:
# False

# %%
price==500
# Out:
# True

# %%
l=[1,2,3,4,5,6]
if 2 in l:
    print("try to perform task")
else:
    print("do not perform task")
# Out:
# try to perform task

# %%
if 60 in l:
    print("yes")
else:
    print("no")
# Out:
# no

# %%
l
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# all the condition are true then it will execute only first right condition
if 1 in l:
    print("try to do addition")
elif 2 in l:
    print("try to do substraction")
elif 3 in l:
    print("try to do multiplication")
# Out:
# try to do addition

# %%
if 10 in l:
    print("try to do addition")
elif 2 in l:
    print("try to do substraction")
elif 3 in l:
    print("try to do multiplication")
# Out:
# try to do substraction

# %%
# whenever you write block with "if" it becomes a complete new block
if 10 in l:
    print("try to do addition")
elif 2 in l:
    print("try to do substraction")
elif 3 in l:
    print("try to do multiplication")
if 4 in l:
    print("this is new statement")
# Out:
# try to do substraction
# this is new statement

# %%
# nasted blocks

# %%
price = int(input())
if price <500:
    print("I will be able to buy something")
    if price < 400:
        print("I will be able to buy a jacket")
    elif price < 300:
        print("I will be able to buy a shirt")
    else:
        print("I will be able to buy a anything")
else:
    print("I wont be able to buy with this price")
# Out:
# 444
# I will be able to buy something
# I will be able to buy a anything

# %%
price = int(input())
if price <500:
    print("I will be able to buy something")
    if price < 400:
        print("I will be able to buy a jacket")
    elif price < 300:
        print("I will be able to buy a shirt")
        if price<200:
            print("I would be like to do something")
    else:
        print("I will be able to buy a anything")
else:
    print("I wont be able to buy with this price") 
    if price>500:
            print("lets try something else")
# Out:
# 523
# I wont be able to buy with this price
# lets try something else

# %% [markdown]
# class task
# marks=600,
# condition is
# if marks>600 then able to get admission
# if marks<600 then no GRE
# if marks<500 then toffel
# if marks<400 then try something else
# else no gre

# %%
marks=int(input())
if marks<600:
    print("able to get admission")
elif marks<600:
    print("No GRE")
    if marks<500:
        print("toffel")
    if marks<400:
        print("Try something else")
else:
    print(" gre")
# Out:
# 123
# able to get admission

# %%
marks=int(input())
if marks<600:
    print("NO GRE")
    if marks<500:
        print("try something else")
    else:
        print("You got toffel")
else:
    print("you got GRE")
# Out:
# 123
# NO GRE
# try something else

# %%
val = float(input("enter a floating point number "))
if val>=0:
    if val==0:
        print("entered value is zaro")
    else:
        print("entered value is positive number")
else:
    print("entered number is negative number")
# Out:
# enter a floating point number 145
# entered value is positive number

# %% [markdown]
# true or false  = true;
#
# false or ture  = true;
#
# true or true   = true;
#
# false or false = false;

# %%
# condition can be true or false
a=10
if a<10 or a==10:
    print("try to do something")
# Out:
# try to do something

# %%
a=10
if a<10 or a>10:
    print("try to do something")

# %% [markdown]
# true or false  = false;
#
# false or ture  = false;
#
# false or false = false;
#
# true or true   = true;

# %%
a=10
if a<10 and a==10:
    print("try to do something")

# %%
a=10
if a<10 and a>10:
    print("try to do something")

# %%
a="sudh"
if a=="sudh" and a=="Sudh":
    print("tyr something")

# %%
a="sudh"
if a=="sudh" or a=="Sudh":
    print("tyr something")
# Out:
# tyr something

# %%
a=10
b=11
c=13
d=14
if a==9 and b==11 and c==12 and d==13:
    print("lets do something")

# %%
d={"key1":"value", "key2":"sudh", "key3":"ineuron"}

# %%
d["key1"]
# Out:
# 'value'

# %%
if d["key1"]=="value" and d["key2"]=="sudh" and d["key3"]=="ineuron":
    print("all the values are verified")
    print(d.values())
# Out:
# all the values are verified
# dict_values(['value', 'sudh', 'ineuron'])

# %%
if d["key1"]=="value" and d["key2"]=="Sudh" and d["key3"]=="ineuron":
    print("all the values are verified")
    print(d.values())
else:
    print("all the values are not verified")
# Out:
# all the values are not verified

# %%
l=[1,2,3,4,5,"sudh",234.45]

# %%
l
# Out:
# [1, 2, 3, 4, 5, 'sudh', 234.45]

# %%
for i in l:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# sudh
# 234.45

# %%
for i in l:
    print(i+1)
# Out:
# 2
# 3
# 4
# 5
# 6
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13112/949430040.py in <module>
#       1 for i in l:
# ----> 2     print(i+1)
#
# TypeError: can only concatenate str (not "int") to str

# %%
for i in l:
    if type(i)==int:
        print(i+1)
    elif type(i)==str:
        print(i+str(1))
# Out:
# 2
# 3
# 4
# 5
# 6
# sudh1

# %%
for i in l:
    if type(i)==int or type(i)==float:
        print(i+1)
    elif type(i)==str:
        print(i+str(1))
# Out:
# 2
# 3
# 4
# 5
# 6
# sudh1
# 235.45

# %%
for i in l:
    if type(i)==int:
        print(i)
    else:
        print("thats it")
# Out:
# 1
# 2
# 3
# 4
# 5
# thats it
# thats it

# %%
l1=[]
for i in l:
    if type(i)==int:
        l1.append(i)

# %%
l1
# Out:
# [1, 2, 3, 4, 5]
