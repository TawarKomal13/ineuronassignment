# %% [markdown]
# # variables: use just to hold the data which we are going to process

# %%
# variable
a=10

# %%
a
# Out:
# 10

# %%
a-2
# Out:
# 8

# %%
b="this is first lecture"

# %%
type(b)
# Out:
# str

# %%
c=3.21

# %%
type(c)
# Out:
# float

# %%
d=True

# %%
type(d)
# Out:
# bool

# %%
e=False

# %%
type(e)
# Out:
# bool

# %%
# True=1 & False=0
True - False
# Out:
# 1

# %%
True-True
# Out:
# 0

# %%
True/False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2960/2794436645.py in <module>
# ----> 1 True/False
#
# ZeroDivisionError: division by zero

# %%
True*False
# Out:
# 0

# %%
n=5+7j

# %%
type(n)
# Out:
# complex

# %%
False/True
# Out:
# 0.0

# %%
n+n
# Out:
# (10+14j)

# %%
0/1
# Out:
# 0.0

# %%
n.conjugate
# Out:
# <function complex.conjugate>

# %%
n.imag
# Out:
# 7.0

# %%
n.real
# Out:
# 5.0

# %%
b="this is first lecture"
type(b)
# Out:
# str

# %% [markdown]
# # data types:

# %% [markdown]
# list is a kind of entity where we can store n number of data or heterogeneous homogenous any amount of data  at a time

# %%
l=[3,4,5,6,"sudh", True, 5+3j, 345]
l
# Out:
# [3, 4, 5, 6, 'sudh', True, (5+3j), 345]

# %%
type(l)
# Out:
# list

# %%
 l[5]
# Out:
# True

# %%
l[6]
# Out:
# (5+3j)

# %% [markdown]
# tuple: notation is (),
# visible difference between tuple and list is brackets but there are many other differences also like mutability and immutability

# %%
t=(3,4,5,6,"sudh", True, 5+3j, 345)

# %%
t
# Out:
# (3, 4, 5, 6, 'sudh', True, (5+3j), 345)

# %%
type(t)
# Out:
# tuple

# %% [markdown]
# dictionary

# %%
d={'a':'komal', "b":"tawar"}

# %%
d
# Out:
# {'a': 'komal', 'b': 'tawar'}

# %%
type(d)
# Out:
# dict
