# %%
# variable
a=10

# %%
a
# Out:
# 10

# %%
a-2
# Out:
# 8

# %%
b="this is first lecture"

# %%
type(b)
# Out:
# str

# %%
c=3.21

# %%
type(c)
# Out:
# float

# %%
d=True

# %%
type(d)
# Out:
# bool

# %%
e=False

# %%
type(e)
# Out:
# bool

# %%
# True=1 & False=0
True - False
# Out:
# 1

# %%
True-True
# Out:
# 0

# %%
True/False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10612/2794436645.py in <module>
# ----> 1 True/False
#
# ZeroDivisionError: division by zero

# %%
True*False
# Out:
# 0

# %%
n=5+7j

# %%
type(n)
# Out:
# complex

# %%
False/True
# Out:
# 0.0
