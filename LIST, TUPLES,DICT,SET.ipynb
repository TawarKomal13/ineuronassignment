# %% [markdown]
# # list: kind of entity where we can store any kind of dataset

# %%
l=[1,2,3, "sudh",45.67, True]

# %% [markdown]
# list traversal operation

# %%
 l[0]
# Out:
# 1

# %%
l[-1]
# Out:
# True

# %%
l[0:5]
# Out:
# [1, 2, 3, 'sudh', 45.67]

# %%
len(l)
# Out:
# 6

# %%
l[::-1]
# Out:
# [True, 45.67, 'sudh', 3, 2, 1]

# %%
l[0:100]
# Out:
# [1, 2, 3, 'sudh', 45.67, True]

# %%
l[0:100:2]
# Out:
# [1, 3, 45.67]

# %%
l[0:8:-1]
# Out:
# []

# %%
l[:3]
# Out:
# [1, 2, 3]

# %%
l+["sudh"]
# Out:
# [1, 2, 3, 'sudh', 45.67, True, 'sudh']

# %%
l*2
# Out:
# [1, 2, 3, 'sudh', 45.67, True, 1, 2, 3, 'sudh', 45.67, True]

# %% [markdown]
# IN OPERATOR

# %%
60 in l
# Out:
# False

# %%
3 in l
# Out:
# True

# %%
max(l)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8008/1790536805.py in <module>
# ----> 1 max(l)
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
l1=[1,2,3,4,5]

# %%
max(l1)
# Out:
# 5

# %%
l2=["sudh", "ineuron", "kumar"]

# %%
max(l2)
# Out:
# 'sudh'

# %%
min(l1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8008/1693498718.py in <module>
# ----> 1 min(l1)
#
# NameError: name 'l1' is not defined

# %%
min(l2)
# Out:
# 'ineuron'

# %%
l.append("kumar")

# %%
l
# Out:
# [1, 2, 3, 'sudh', 45.67, True, 'kumar']

# %%
l.append([1,2,3,4])
l
# Out:
# [1, 2, 3, 'sudh', 45.67, True, 'kumar', [1, 2, 3, 4]]

# %%
l.pop(0)
# Out:
# 1

# %%
l
# Out:
# [2, 3, 'sudh', 45.67, True, 'kumar']

# %%
l.pop()
# Out:
# [1, 2, 3, 4]

# %%
l
# Out:
# [2, 3, 'sudh', 45.67, True, 'kumar']

# %%
l.reverse()

# %%
l
# Out:
# ['kumar', True, 45.67, 'sudh', 3, 2]

# %%
l[::-1]
# Out:
# [2, 3, 'sudh', 45.67, True, 'kumar']

# %%
l
# Out:
# ['kumar', True, 45.67, 'sudh', 3, 2]

# %%
l.append([1,2,3])

# %%
l
# Out:
# ['kumar', True, 45.67, 'sudh', 3, 2, [1, 2, 3]]

# %%
l.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8008/4149526160.py in <module>
# ----> 1 l.sort()
#
# TypeError: '<' not supported between instances of 'bool' and 'str'

# %%
l1
# Out:
# [1, 2, 3, 4, 5]

# %%
l1.sort()

# %%
l1
# Out:
# [1, 2, 3, 4, 5]

# %%
l3=[8,9,2,34,23,1,0]

# %%
l3.sort()

# %%
l3
# Out:
# [0, 1, 2, 8, 9, 23, 34]

# %%
l3.sort(reverse=True)

# %%
l3
# Out:
# [34, 23, 9, 8, 2, 1, 0]

# %%
l1 = [2,3,4]
l2=[6,7,8]
l3=[3,2,4]

# %%
l4=[l1,l2,l3]

# %%
l4
# Out:
# [[2, 3, 4], [6, 7, 8], [3, 2, 4]]

# %%
l4[2]
# Out:
# [3, 2, 4]

# %%
l4[2][1]
# Out:
# 2

# %%
l
# Out:
# ['kumar', True, 45.67, 'sudh', 3, 2, [1, 2, 3]]

# %%
l.count(2)
# Out:
# 1

# %%
l5=[3,4,3,3,3,3,5]

# %%
l5.count(3)
# Out:
# 5

# %%
l
# Out:
# ['kumar', True, 45.67, 'sudh', 3, 2, [1, 2, 3]]

# %%
l.append("ineuron")

# %%
l
# Out:
# ['kumar', True, 45.67, 'sudh', 3, 2, [1, 2, 3], 'ineuron']

# %%
l.append([4,56,"sudh"])

# %%
l
# Out:
# ['kumar', True, 45.67, 'sudh', 3, 2, [1, 2, 3], 'ineuron', [4, 56, 'sudh']]

# %%
l.extend("sudh")

# %%
l
# Out:
# ['kumar',
#  True,
#  45.67,
#  'sudh',
#  3,
#  2,
#  [1, 2, 3],
#  'ineuron',
#  [4, 56, 'sudh'],
#  's',
#  'u',
#  'd',
#  'h']

# %%
l6=[1,2,3]

# %%
l6.append([4,6,5])

# %%
l6
# Out:
# [1, 2, 3, [4, 6, 5]]

# %%
l6.append("sudh")

# %%
l6
# Out:
# [1, 2, 3, [4, 6, 5], 'sudh']

# %%
l6.extend(45)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8008/3761217359.py in <module>
# ----> 1 l6.extend(45)
#
# TypeError: 'int' object is not iterable

# %%
l6.append(45)

# %%
l6
# Out:
# [1, 2, 3, [4, 6, 5], 'sudh', 45]

# %%
l6.extend([56,34,21])

# %%
l6
# Out:
# [1, 2, 3, [4, 6, 5], 'sudh', 45, 56, 34, 21]

# %%
l6.extend("sudh")

# %%
l6
# Out:
# [1, 2, 3, [4, 6, 5], 'sudh', 45, 56, 34, 21, 's', 'u', 'd', 'h']

# %%
l6.index(1)
# Out:
# 0

# %%
l6.index(45)
# Out:
# 5

# %%
l7=[1,2,3,4,5,6,6,6,7,8]

# %%
l7.index(6)
# Out:
# 5

# %%
l=[1,2,3,4,5,45]

# %%
l.insert(1 , [1,2,3,4])

# %%
l
# Out:
# [1, [1, 2, 3, 4], 2, 3, 4, 5, 45]

# %%
l.insert(5, "komal")

# %%
l
# Out:
# [1, [1, 2, 3, 4], 2, 3, 4, 'komal', 5, 45]

# %%
l.pop()
# Out:
# 45

# %%
l
# Out:
# [1, [1, 2, 3, 4], 2, 3, 4, 'komal', 5]

# %%
l.pop(2)
# Out:
# 2

# %%
l
# Out:
# [1, [1, 2, 3, 4], 3, 4, 'komal', 5]

# %%
l.remove(100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8008/1079903665.py in <module>
# ----> 1 l.remove(100)
#
# ValueError: list.remove(x): x not in list

# %%
l.remove(4)

# %%
l
# Out:
# [1, [1, 2, 3, 4], 3, 'komal', 5]

# %%
l.remove(3)

# %%
l
# Out:
# [1, [1, 2, 3, 4], 'komal', 5]

# %%
l=[1,2,3,4]

# %%
l[2]
# Out:
# 3

# %%
l[2]="sudh"

# %%
l
# Out:
# [1, 2, 'sudh', 4]

# %%
# strings are immutable in item assignment operation
s="ineuron"

# %%
s[2]='z'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8008/1993983954.py in <module>
# ----> 1 s[2]='z'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# # TUPLE

# %%
t=(4,5,6,7,"sudh",45.67,True)

# %%
type(t)
# Out:
# tuple

# %%
t[0]
# Out:
# 4

# %%
t[0:4]
# Out:
# (4, 5, 6, 7)

# %%
t[-1]
# Out:
# True

# %%
t
# Out:
# (4, 5, 6, 7, 'sudh', 45.67, True)

# %%
t[0:6:2]
# Out:
# (4, 6, 'sudh')

# %%
t[0:4:-1]
# Out:
# ()

# %%
l=[1,2,3,454,78]

# %%
l[2]="komal"

# %%
l
# Out:
# [1, 2, 'komal', 454, 78]

# %%
t
# Out:
# (4, 5, 6, 7, 'sudh', 45.67, True)

# %%
t[2]="sudh"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8008/1878026976.py in <module>
# ----> 1 t[2]="sudh"
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1=(3,4,5,6)

# %%
t
# Out:
# (4, 5, 6, 7, 'sudh', 45.67, True)

# %%
# this is just a concatination nothing else
t+t1
# Out:
# (4, 5, 6, 7, 'sudh', 45.67, True, 3, 4, 5, 6)

# %%
t.count(3)
# Out:
# 0

# %%
t.count(7)
# Out:
# 1

# %%
t.index(5)
# Out:
# 1

# %%
t
# Out:
# (4, 5, 6, 7, 'sudh', 45.67, True)

# %%
t
# Out:
# (4, 5, 6, 7, 'sudh', 45.67, True)

# %%
t = (3,4,56,7,"sudh")

# %%
list(t)
# Out:
# [3, 4, 56, 7, 'sudh']

# %%
t2=list(t)

# %%
t2
# Out:
# [3, 4, 56, 7, 'sudh']

# %%
tuple(t2)
# Out:
# (3, 4, 56, 7, 'sudh')

# %%
str(t2)
# Out:
# "[3, 4, 56, 7, 'sudh']"

# %% [markdown]
# # DICTIONARY

# %%
# keys must be unique values can be repeated
d={}

# %%
type(d)
# Out:
# dict

# %%
d1={1}

# %%
type(d1)
# Out:
# set

# %%
d2={"key1":"value", 234:"xyz", "name":"sudh", "no":34324546}

# %%
type(d2)
# Out:
# dict

# %%
d2['name']
# Out:
# 'sudh'

# %%
d2['no']
# Out:
# 34324546

# %%
d3={"name":"sudh", "tech":["python", "ml","cv","dl","big data","data analyst"]}

# %%
d3
# Out:
# {'name': 'sudh',
#  'tech': ['python', 'ml', 'cv', 'dl', 'big data', 'data analyst']}

# %%
d3['tech']
# Out:
# ['python', 'ml', 'cv', 'dl', 'big data', 'data analyst']

# %%
'python' in d3['tech']
# Out:
# True

# %%
d4={"name":"ineuron","contact_info":123456789,"name":"sudh"}

# %%
# override latest value
d4
# Out:
# {'name': 'sudh', 'contact_info': 123456789}

# %%
d4["k1"]="zzz"

# %%
d4
# Out:
# {'name': 'sudh', 'contact_info': 123456789, 'k1': 'zzz'}

# %%
d4['name1']:"xyz"

# %%
d4
# Out:
# {'name': 'sudh', 'contact_info': 123456789, 'k1': 'zzz'}

# %%
d4['k2']:"xyz"

# %%
d4
# Out:
# {'name': 'sudh', 'contact_info': 123456789, 'k1': 'zzz'}

# %%
d4['k2']=d2

# %%
d4
# Out:
# {'name': 'sudh',
#  'contact_info': 123456789,
#  'k1': 'zzz',
#  'k2': {'key1': 'value', 234: 'xyz', 'name': 'sudh', 'no': 34324546}}

# %%
d4["k2"]
# Out:
# {'key1': 'value', 234: 'xyz', 'name': 'sudh', 'no': 34324546}

# %%
d4["k2"]["no"]
# Out:
# 34324546

# %%
d5={@:"dkddk"}
# Out:
#   File "C:\Users\Komal\AppData\Local\Temp/ipykernel_8008/4135971910.py", line 1
#     d5={@:"dkddk"}
#         ^
# SyntaxError: invalid syntax

# %%
d5={_:"sdsd"}

# %%
d5[_]
# Out:
# 'sdsd'

# %%
d6={(1,2,1,2,3,):"fsfs"}

# %%
d6
# Out:
# {(1, 2, 1, 2, 3): 'fsfs'}

# %%
d6[(1, 2, 1, 2, 3)]
# Out:
# 'fsfs'

# %%
d7={[1,2,3,4]:"dhshsh"}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8008/1744595348.py in <module>
# ----> 1 d7={[1,2,3,4]:"dhshsh"}
#
# TypeError: unhashable type: 'list'

# %%
d8={{3:4}:"fsfs"}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8008/3865754260.py in <module>
# ----> 1 d8={{3:4}:"fsfs"}
#
# TypeError: unhashable type: 'dict'

# %%
d2
# Out:
# {'key1': 'value', 234: 'xyz', 'name': 'sudh', 'no': 34324546}

# %%
d3
# Out:
# {'name': 'sudh',
#  'tech': ['python', 'ml', 'cv', 'dl', 'big data', 'data analyst']}

# %%
d2+d3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8008/2884743602.py in <module>
# ----> 1 d2+d3
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
d2.keys()
# Out:
# dict_keys(['key1', 234, 'name', 'no'])

# %%
d2.values()
# Out:
# dict_values(['value', 'xyz', 'sudh', 34324546])

# %%
d2.items()
# Out:
# dict_items([('key1', 'value'), (234, 'xyz'), ('name', 'sudh'), ('no', 34324546)])

# %% [markdown]
# # SET

# %%
s={3,2,4,5,6,7}

# %%
type(s)
# Out:
# set

# %%
s1={3,4,4,5,6,6,7,7,8,8,9,9,0,0,0}

# %%
s1
# Out:
# {0, 3, 4, 5, 6, 7, 8, 9}

# %%
s2={3245,2456,4545,6565,5879,5478}

# %%
s2
# Out:
# {2456, 3245, 4545, 5478, 5879, 6565}

# %%
s3={"sudh",345,34,12,645,12.5,"b",6}

# %%
s3
# Out:
# {12, 12.5, 34, 345, 6, 645, 'b', 'sudh'}

# %%
s2
# Out:
# {2456, 3245, 4545, 5478, 5879, 6565}

# %%
s3
# Out:
# {12, 12.5, 34, 345, 6, 645, 'b', 'sudh'}

# %%
s3[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8008/397937684.py in <module>
# ----> 1 s3[0]
#
# TypeError: 'set' object is not subscriptable

# %%
list(s3)
# Out:
# [34, 645, 6, 12, 12.5, 'sudh', 345, 'b']

# %%
tuple(s3)
# Out:
# (34, 645, 6, 12, 12.5, 'sudh', 345, 'b')

# %%
l=[2,3,4,565,7,7,7,7,7,7,7,777,7,7,7,]

# %%
l
# Out:
# [2, 3, 4, 565, 7, 7, 7, 7, 7, 7, 7, 777, 7, 7, 7]

# %%
set(l)
# Out:
# {2, 3, 4, 7, 565, 777}

# %%
l=list(set(l))

# %%
l
# Out:
# [2, 3, 4, 7, 777, 565]

# %%
s2.add(34)

# %%
s2
# Out:
# {34, 2456, 3245, 4545, 5478, 5879, 6565}

# %%
s2.add([1,2,3,4,5])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8008/1499940319.py in <module>
# ----> 1 s2.add([1,2,3,4,5])
#
# TypeError: unhashable type: 'list'

# %%
s={(1,2,3,4,5),3,4,5,6,7}

# %%
s
# Out:
# {(1, 2, 3, 4, 5), 3, 4, 5, 6, 7}

# %%
s1={[1,2,3,4,5,6],345,345}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8008/1794582243.py in <module>
# ----> 1 s1={[1,2,3,4,5,6],345,345}
#
# TypeError: unhashable type: 'list'

# %%
s
# Out:
# {(1, 2, 3, 4, 5), 3, 4, 5, 6, 7}

# %%
s.remove(3)

# %%
s
# Out:
# {(1, 2, 3, 4, 5), 4, 5, 6, 7}

# %%
s.discard(4)

# %%
s
# Out:
# {(1, 2, 3, 4, 5), 5, 6, 7}

# %%
s.remove(3456)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8008/2075491887.py in <module>
# ----> 1 s.remove(3456)
#
# KeyError: 3456

# %%
s.discard(3456)

# %%
s
# Out:
# {(1, 2, 3, 4, 5), 5, 6, 7}

# %% [markdown]
# # tasks

# %% [markdown]
# QUESTIONS
# l=[3,4,5,6,7,[23,456,67,8,78,78],[345,56,87,8,98,9],(234,6657,6),{"key1":"sudh",234:[23,45,656]}]
# 1.Try to reverse a list
# 2.try to access234 out of this list
# 3.try to access 456
# 4.try to extract only list collection from list l
# 5.try to extract "sudh"
# 6.try to list all the key element available in list
# 7.try to extract all the value element from dict available in list
