# %% [markdown]
# # string

# %%
s="ineuron"

# %%
type(s)
# Out:
# str

# %%
# for indexing always use [] this brackets  
s[0]
# Out:
# 'i'

# %%
s[5]
# Out:
# 'o'

# %%
s[-3]
# Out:
# 'r'

# %%
s1="sudh"

# %%
s1[1]
# Out:
# 'u'

# %%
s1[-1]
# Out:
# 'h'

# %%
s2="this is my vry first programming class's"

# %%
s2
# Out:
# "this is my vry first programming class's"

# %%
s2[1]
# Out:
# 'h'

# %% [markdown]
# SLICING

# %%
s2[1:5]
# Out:
# 'his '

# %%
s2[5:9]
# Out:
# 'is m'

# %%
# s2[initiate:upto:difference]
s2[6:30:2]
# Out:
# 'sm r is rgam'

# %%
s="sudhanshu"

# %%
s[0:9:2]
# Out:
# 'sdasu'

# %%
s
# Out:
# 'sudhanshu'

# %%
# conclusion:is starting from 0 to 8 is the direction but the difference is -1 so it moves to possitive direction and goes in negative direction so it gives contradiction
s[0:8:-1]
# Out:
# ''

# %%
s[8:0:-1]
# Out:
# 'uhsnahdu'

# %%
s[8:0:-2]
# Out:
# 'usad'

# %%
s[:-3]
# Out:
# 'sudhan'

# %%
s[-2:]
# Out:
# 'hu'

# %%
s[-5:]
# Out:
# 'anshu'

# %%
s[::1]
# Out:
# 'sudhanshu'

# %%
s[::2]
# Out:
# 'sdasu'

# %%
s[::-1]
# Out:
# 'uhsnahdus'

# %%
s2[::-1]
# Out:
# "s'ssalc gnimmargorp tsrif yrv ym si siht"

# %%
s3="ineuron"

# %%
s3[::-1]
# Out:
# 'norueni'

# %%
# contradiction
s3[-2:-7:1]
# Out:
# ''

# %%
s3[-7:-2:1]
# Out:
# 'ineur'

# %%
s3[5:0]
# Out:
# ''

# %%
s3[-7:0:1]
# Out:
# ''

# %%
s3[:-1:-1]
# Out:
# ''

# %%
s
# Out:
# 'sudhanshu'

# %% [markdown]
# typecasting

# %%
s+1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7220/3519921828.py in <module>
# ----> 1 s+1
#
# TypeError: can only concatenate str (not "int") to str

# %%
s+"1"
# Out:
# 'sudhanshu1'

# %%
s+str(11)
# Out:
# 'sudhanshu11'

# %%
len(s)
# Out:
# 9

# %%
s
# Out:
# 'sudhanshu'

# %%
s*4
# Out:
# 'sudhanshusudhanshusudhanshusudhanshu'

# %%
s*2
# Out:
# 'sudhanshusudhanshu'

# %%
s.count('h')
# Out:
# 2

# %%
s.count("dha")
# Out:
# 1

# %%
s.split('u')
# Out:
# ['s', 'dhansh', '']

# %%
c
# Out:
# ['su', 'anshu']

# %%
type(s)
# Out:
# str

# %%
type(s.split('u') )
# Out:
# list

# %% [markdown]
# for multiline code always use triple colan ''' ''' else python will give an error

# %%
sw='''There are various data types in Python.
Some of the important types are listed below. 
Python Numbers Integers, floating point numbers 
and complex numbers fall under Python number'''

# %%
sw
# Out:
# 'There are various data types in Python.\nSome of the important types are listed below. \nPython Numbers Integers, floating point numbers \nand complex numbers fall under Python number'

# %%
sw.split(' ')
# Out:
# ['There',
#  'are',
#  'various',
#  'data',
#  'types',
#  'in',
#  'Python.\nSome',
#  'of',
#  'the',
#  'important',
#  'types',
#  'are',
#  'listed',
#  'below.',
#  '\nPython',
#  'Numbers',
#  'Integers,',
#  'floating',
#  'point',
#  'numbers',
#  '\nand',
#  'complex',
#  'numbers',
#  'fall',
#  'under',
#  'Python',
#  'number']

# %%
sw.upper()
# Out:
# 'THERE ARE VARIOUS DATA TYPES IN PYTHON.\nSOME OF THE IMPORTANT TYPES ARE LISTED BELOW. \nPYTHON NUMBERS INTEGERS, FLOATING POINT NUMBERS \nAND COMPLEX NUMBERS FALL UNDER PYTHON NUMBER'

# %%
sw
# Out:
# 'There are various data types in Python.\nSome of the important types are listed below. \nPython Numbers Integers, floating point numbers \nand complex numbers fall under Python number'

# %%
sw=sw.upper()

# %%
sw
# Out:
# 'THERE ARE VARIOUS DATA TYPES IN PYTHON.\nSOME OF THE IMPORTANT TYPES ARE LISTED BELOW. \nPYTHON NUMBERS INTEGERS, FLOATING POINT NUMBERS \nAND COMPLEX NUMBERS FALL UNDER PYTHON NUMBER'

# %%
sw.lower()
# Out:
# 'there are various data types in python.\nsome of the important types are listed below. \npython numbers integers, floating point numbers \nand complex numbers fall under python number'

# %%
s="sudhanshu kumar"

# %%
s.title()
# Out:
# 'Sudhanshu Kumar'

# %%
s.capitalize()
# Out:
# 'Sudhanshu kumar'

# %%
s= 'Sudhanshu KuMAR'

# %%
s.swapcase()
# Out:
# 'sUDHANSHU kUmar'

# %%
''.join(reversed(s))
# Out:
# 'RAMuK uhsnahduS'

# %%
s[::-1]
# Out:
# 'RAMuK uhsnahduS'

# %%
s= "   sudh   "

# %%
s.strip()
# Out:
# 'sudh'

# %%
s="  su  dh  "

# %%
s
# Out:
# '  su  dh  '

# %%
s.lstrip()
# Out:
# 'su  dh  '

# %%
s.rstrip()
# Out:
# '  su  dh'

# %%
" " . join("sudhanshu")
# Out:
# 's u d h a n s h u'

# %%
"a" . join("sudhanshu")
# Out:
# 'sauadahaaanasahau'

# %%
s
# Out:
# '  su  dh  '

# %%
s="sudh"

# %%
s.center(20, 'z')
# Out:
# 'zzzzzzzzsudhzzzzzzzz'

# %%
s.center(30, '#')
# Out:
# '#############sudh#############'

# %%
s.isupper()
# Out:
# False

# %%
s1="SUDH"

# %%
s1.isupper()
# Out:
# True

# %%
s.islower()
# Out:
# True

# %%
s
# Out:
# 'sudh'

# %%
s.isspace()
# Out:
# False

# %%
s4 = " "

# %%
s4.isspace()
# Out:
# True

# %%
s.isdigit()
# Out:
# False

# %%
s5='5423'

# %%
s5
# Out:
# '5423'

# %%
s5.isdigit()
# Out:
# True

# %%
s.isalnum()
# Out:
# True

# %%
s.isalpha()
# Out:
# True

# %%
s7="2456shdhs"

# %%
s7.isalpha()
# Out:
# False

# %%
s
# Out:
# 'sudh'

# %%
s.startswith('i')
# Out:
# False

# %%
s.startswith('S')
# Out:
# False

# %%
s.startswith('s')
# Out:
# True

# %%
s.endswith('u')
# Out:
# False

# %%
s.endswith('h')
# Out:
# True

# %%
s
# Out:
# 'sudh'

# %%
s.isdigit()
# Out:
# False

# %%
s.isnumeric()
# Out:
# False

# %%
s.isascii()
# Out:
# True

# %%
s8=" "

# %%
s8.isspace()
# Out:
# True

# %%
s9=" 5 "
s9.isspace()
# Out:
# False

# %%
s='2356'
s.isdigit()
# Out:
# True

# %%
s1 = "fakshfbwye"
s1.isnumeric()
# Out:
# False

# %%
s2 = "245 3548 4587"
s2.isnumeric()
# Out:
# False

# %%
s.isdigit()
# Out:
# True

# %%
s.isnumeric()
# Out:
# True

# %%
s2.isnumeric()
# Out:
# False

# %%
s2.isdigit()
# Out:
# False

# %%
s = "sudh"

# %%
reversed(s)

# %%
'd' .join('ineuron')
# Out:
# 'idndedudrdodn'

# %%
''.join(reversed('sudh'))
# Out:
# 'hdus'

# %%
s='45.35685'

# %%
s.isdigit()
# Out:
# False

# %%
s.isnumeric()
# Out:
# False

# %%
s='Sudhanshu\tkumae\tineuron'

# %%
s
# Out:
# 'Sudhanshu\tkumae\tineuron'

# %%
s.expandtabs()
# Out:
# 'Sudhanshu       kumae   ineuron'

# %%
s = "this is My First Python progrmming class and I an learNING python and its function"
# 1} Try to extract data from idex one to index 300 with a jump of 3
# 2} Try to reverse a string without using reverse function.
# 3} Try to split a string after conversion in entire string in uppercase
# 4} Tre to split a string into lower case
# 5} Try to capitalize the whole string
# 6} Write a difference isalnum() and isalpha
# 7} try to give an example tp expand tab
# 8} Give and examp,e of strip , lstrip and rstrip
# 9} Replace a string character by another character by taking your own example
# 10} Try to give a definition of string center function with and example
# 11} Write your own definition of copiler and interpretor with copy paste from internet in your own language
# 12} Python is a interpretated language of compiled language give a clear answer with your understanding
# 13} try to answer a usecase of python with your understanding.
#
# you have to submit a jupyter notebook to shivan@ineuron.ai

# %%
https://codeshare.io/X8PY8Y
